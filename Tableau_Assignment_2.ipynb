# %% [markdown]
# # Tableau_Assignment_2

# %% [markdown]
# ![sheet%201.png](attachment:sheet%201.png)

# %% [markdown]
# ![sheet%202.png](attachment:sheet%202.png)

# %% [markdown]
# ![sheet%203.png](attachment:sheet%203.png)
