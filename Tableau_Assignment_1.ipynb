# %% [markdown]
# # Tableau_Assignment_1

# %% [markdown]
# Show largest selling products and also show what % of sales is coming
# from which regions.

# %% [markdown]
# ![Screenshot%202022-07-28%20172729.png](attachment:Screenshot%202022-07-28%20172729.png)
