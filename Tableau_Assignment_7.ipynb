# %% [markdown]
# # Tableau_Assignment_7

# %% [markdown]
# ![Screenshot%202022-07-30%20135422.png](attachment:Screenshot%202022-07-30%20135422.png)

# %% [markdown]
# ![2.png](attachment:2.png)

# %% [markdown]
# ![3.png](attachment:3.png)

# %% [markdown]
# ![5.png](attachment:5.png)
